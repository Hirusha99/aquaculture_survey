# %%
import pandas as pd

# %%
data = pd.read_csv("D:/Research/madhavii/implementation/survey data.csv")
data.head()
# Out:
#      ID  Area (Ha 1)  INITIAL WEIGHT/kg DENSITY 1 (total stock/Ha)  \
# 0  J002          0.4               0.08                      12500
# 1  J003          0.4               0.08                      10000
# 2  J004          0.8               0.10                      18750
# 3  J005          1.0               0.10                      10000
# 4  J006          0.4               0.08                      10000
#
#    HARVEST NO. 1  AVG WEIGHT 1  PRODUCTION 1  PRODUCTION 1/Ha  DISTANCE/m  \
# 0         5000.0         0.375          1875             4688         300
# 1         3000.0         0.300           900             2250         300
# 2        14000.0         0.400          5600             7000         150
# 3         9000.0         0.450          4050             4050         200
# 4         5000.0         0.350          1750             4375         100
#
#    VEGETATION%  AVERAGE_DEPTH/ft  PENS  DURATIONMONTHS
# 0           60                 2     2               5
# 1           10                 6     2               8
# 2           60                 5     3               8
# 3           75                 3     1               6
# 4           20                 3     1              10

# %%
print(data.describe())
# Out:
#        Area (Ha 1)  INITIAL WEIGHT/kg  HARVEST NO. 1  AVG WEIGHT 1  \
# count    43.000000          43.000000      42.000000     43.000000
# mean      1.107907           0.098488   11210.714286      0.425000
# std       1.140310           0.036245   14439.493335      0.075198
# min       0.400000           0.025000     700.000000      0.300000
# 25%       0.400000           0.080000    3600.000000      0.350000
# 50%       0.800000           0.100000    5750.000000      0.450000
# 75%       1.000000           0.110000   10750.000000      0.450000
# max       4.000000           0.200000   65000.000000      0.600000
#
#        PRODUCTION 1  PRODUCTION 1/Ha   DISTANCE/m  VEGETATION%  \
# count     43.000000        43.000000    43.000000    43.000000
# mean    4483.558140      4322.186047   558.255814    55.000000
# std     5238.840458      3087.504565   514.970970    19.970216
# min      280.000000       656.000000    50.000000    10.000000
# 25%     1620.000000      2510.000000   150.000000    50.000000
# 50%     2520.000000      4050.000000   400.000000    50.000000
# 75%     4750.000000      4594.000000  1000.000000    67.500000
# max    22050.000000     19500.000000  2000.000000   100.000000
#
#        AVERAGE_DEPTH/ft       PENS  DURATIONMONTHS
# count         43.000000  43.000000       43.000000
# mean           3.046512   1.395349        8.511628
# std            1.022450   0.728323        2.529559
# min            1.000000   1.000000        4.000000
# 25%            2.000000   1.000000        6.000000
# 50%            3.000000   1.000000        8.000000
# 75%            3.500000   2.000000       10.000000
# max            6.000000   4.000000       14.000000

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          43 non-null     object
#  1   Area (Ha 1)                 43 non-null     float64
#  2   INITIAL WEIGHT/kg           43 non-null     float64
#  3   DENSITY 1 (total stock/Ha)  43 non-null     object
#  4   HARVEST NO. 1               42 non-null     float64
#  5   AVG WEIGHT 1                43 non-null     float64
#  6   PRODUCTION 1                43 non-null     int64
#  7   PRODUCTION 1/Ha             43 non-null     int64
#  8   DISTANCE/m                  43 non-null     int64
#  9   VEGETATION%                 43 non-null     int64
#  10  AVERAGE_DEPTH/ft            43 non-null     int64
#  11  PENS                        43 non-null     int64
#  12  DURATIONMONTHS              43 non-null     int64
# dtypes: float64(4), int64(7), object(2)
# memory usage: 4.5+ KB
# None

# %%
# Check missing values
print(data.isnull().sum())
# Out:
# ID                            0
# Area (Ha 1)                   0
# INITIAL WEIGHT/kg             0
# DENSITY 1 (total stock/Ha)    0
# HARVEST NO. 1                 1
# AVG WEIGHT 1                  0
# PRODUCTION 1                  0
# PRODUCTION 1/Ha               0
# DISTANCE/m                    0
# VEGETATION%                   0
# AVERAGE_DEPTH/ft              0
# PENS                          0
# DURATIONMONTHS                0
# dtype: int64

# %%
data = data.fillna(0)

# %%
# Check duplicate rows
print(data.duplicated().sum())
# Out:
# 0

# %%
(data == '#REF!').sum()
# Out:
# ID                            0
# Area (Ha 1)                   0
# INITIAL WEIGHT/kg             0
# DENSITY 1 (total stock/Ha)    3
# HARVEST NO. 1                 0
# AVG WEIGHT 1                  0
# PRODUCTION 1                  0
# PRODUCTION 1/Ha               0
# DISTANCE/m                    0
# VEGETATION%                   0
# AVERAGE_DEPTH/ft              0
# PENS                          0
# DURATIONMONTHS                0
# dtype: int64

# %%
import numpy as np

data = data.replace('#REF!', np.nan)

# %%
(data == '#REF!').sum()
# Out:
# ID                            0
# Area (Ha 1)                   0
# INITIAL WEIGHT/kg             0
# DENSITY 1 (total stock/Ha)    0
# HARVEST NO. 1                 0
# AVG WEIGHT 1                  0
# PRODUCTION 1                  0
# PRODUCTION 1/Ha               0
# DISTANCE/m                    0
# VEGETATION%                   0
# AVERAGE_DEPTH/ft              0
# PENS                          0
# DURATIONMONTHS                0
# dtype: int64

# %%
data.columns
# Out:
# Index(['ID', 'Area (Ha 1)', 'INITIAL WEIGHT/kg', 'DENSITY 1 (total stock/Ha)',
#        'HARVEST NO. 1', 'AVG WEIGHT 1', 'PRODUCTION 1', 'PRODUCTION 1/Ha',
#        'DISTANCE/m', 'VEGETATION%', 'AVERAGE_DEPTH/ft', 'PENS',
#        'DURATIONMONTHS'],
#       dtype='object')

# %%
y = data["DURATIONMONTHS"]

# %%
y.head()
# Out:
# 0     5
# 1     8
# 2     8
# 3     6
# 4    10
# Name: DURATIONMONTHS, dtype: int64

# %%
x = data.drop(columns=["DURATIONMONTHS", "ID"], axis=1)
x.head()
# Out:
#    Area (Ha 1)  INITIAL WEIGHT/kg DENSITY 1 (total stock/Ha)  HARVEST NO. 1  \
# 0          0.4               0.08                      12500         5000.0
# 1          0.4               0.08                      10000         3000.0
# 2          0.8               0.10                      18750        14000.0
# 3          1.0               0.10                      10000         9000.0
# 4          0.4               0.08                      10000         5000.0
#
#    AVG WEIGHT 1  PRODUCTION 1  PRODUCTION 1/Ha  DISTANCE/m  VEGETATION%  \
# 0         0.375          1875             4688         300           60
# 1         0.300           900             2250         300           10
# 2         0.400          5600             7000         150           60
# 3         0.450          4050             4050         200           75
# 4         0.350          1750             4375         100           20
#
#    AVERAGE_DEPTH/ft  PENS
# 0                 2     2
# 1                 6     2
# 2                 5     3
# 3                 3     1
# 4                 3     1

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
print(X_train.shape)
# Out:
# (34, 11)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\HIRUSHA\\anaconda3\\python.exe'

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\hirusha\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hirusha\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\hirusha\anaconda3\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\hirusha\anaconda3\lib\site-packages (from seaborn) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hirusha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hirusha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hirusha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hirusha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\hirusha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\hirusha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hirusha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hirusha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\hirusha\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hirusha\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hirusha\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2022.7)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\hirusha\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\hirusha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.15.0)

# %%
! conda activate base

# %%
! conda install seaborn

# %%
import seaborn as sns

df_plot = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})

sns.scatterplot(
    x='Actual',
    y='Predicted',
    data=df_plot
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 import seaborn as sns
#       3 df_plot = pd.DataFrame({
#       4     'Actual': y_test,
#       5     'Predicted': y_pred
#       6 })
#       8 sns.scatterplot(
#       9     x='Actual',
#      10     y='Predicted',
#      11     data=df_plot
#      12 )
#
# File c:\Users\HIRUSHA\anaconda3\lib\site-packages\seaborn\__init__.py:2
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File c:\Users\HIRUSHA\anaconda3\lib\site-packages\seaborn\rcmod.py:5
#       3 import matplotlib as mpl
#       4 from cycler import cycler
# ----> 5 from . import palettes
#       8 __all__ = ["set_theme", "set", "reset_defaults", "reset_orig",
#       9            "axes_style", "set_style", "plotting_context", "set_context",
#      10            "set_palette"]
#      13 _style_keys = [
#      14
#      15     "axes.facecolor",
#    (...)
#      50
#      51 ]
#
# File c:\Users\HIRUSHA\anaconda3\lib\site-packages\seaborn\palettes.py:9
#       5 import matplotlib as mpl
#       7 from .external import husl
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11 from ._compat import get_colormap
#
# File c:\Users\HIRUSHA\anaconda3\lib\site-packages\seaborn\utils.py:13
#      11 import pandas as pd
#      12 import matplotlib as mpl
# ---> 13 from matplotlib.colors import to_rgb
#      14 import matplotlib.pyplot as plt
#      15 from matplotlib.cbook import normalize_kwargs
#
# ModuleNotFoundError: No module named 'matplotlib.colors'
